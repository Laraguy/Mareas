# %% [markdown]
# <a href="https://colab.research.google.com/github/Laraguy/Mareas/blob/main/TP_3_Mareas_Lara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Para generar una señal cuya amplitud esté modulada:
#
# $$c(t) = A_c cos (𝜔_ct)$$ señal original (portadora)
#
# $$m(t) = A_m cos(𝜔_m t) $$ señal moduladora
#
# $$AM(t) = [A_c + m(t)] cos(𝜔_c t) $$ Señal de Amplitud Modulada

# %% [markdown]
# # Onda Resultante de las Componentes Armonicas de Marea
#   usando las amplitudes derivadas de la teoria de equilibrio

# %% [markdown]
# (a) periodo de 30 dias, onda de 1m de amplitud
# con frecuencia de 28.9841 °/h (período de 12.42 h).

# %%
t=np.arange(0,24*30) # Eje temporal de un mes de datos horarios
M2=1*np.cos(np.deg2rad(28.9841*t))

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,M2, color= "m")
axs.set(title='M2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',ls=':')

# %% [markdown]
# (b)  Para el mismo perioo una onda de 0.4652 m de amplitud con una frecuencia de 30°/h (período de 12 h).

# %%
S2=0.4652*np.cos(np.deg2rad(30*t))
suma=S2+M2

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,M2,color="m")
axs.plot(t/24,suma, color="coral")
axs.set(title='M2+S2',ylabel='Altura (m)',xlabel='días')
axs.legend(['M2','M2 + S2'])
axs.grid(which='both',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,S2, color= "darkcyan")
axs.set(title='S2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,M2,color="m")
axs.plot(t/24,S2, color="darkcyan")
axs.set(title='M2 y S2',ylabel='Altura (m)',xlabel='días')
axs.legend(['M2',' S2'])
axs.grid(which='both',ls=':')

# %% [markdown]
# (c) para la onda suma obtenida, le sumo otra  onda de 0.1915 m de amplitud y período de 12.66 h.

# %%
N2=0.195*np.cos(np.deg2rad(28.436001*t))
suma_1= suma + N2

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,suma,color="coral")
axs.plot(t/24,suma_1, color="greenyellow")
axs.set(title='M2 + S2+ N2',ylabel='Altura (m)',xlabel='días')
axs.legend(['M2+S2','M2+S2+N2'])
axs.grid(which='both',ls=':')

# %% [markdown]
# (d) a la onda resultante en c se le agregan dos ondas de períodos 23.93 h y 25.82 h, ambas con amplitudes de 0.40 y con fases 90° y 0°, respectivamente.

# %%
K1=0.40*np.cos(np.deg2rad(15.043877*t + 90))
O1=0.40*np.cos(np.deg2rad(13.94268*t))
suma_2= suma_1 + K1 + O1

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,suma_1,color="greenyellow")
axs.plot(t/24,suma_2, color="c")
axs.set(title='M2+S2+N2+K1+O1s',ylabel='Altura (m)',xlabel='días')
axs.legend(['M2+S2+N2','M2 + S2+N2+K1+O1'])
axs.grid(which='both',ls=':')

# %%
K1_mod=0.40*np.cos(np.deg2rad(15.043877*t))
O1=0.40*np.cos(np.deg2rad(13.94268*t))
suma_2_mod= suma_1 + K1_mod + O1

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,suma_1,color="greenyellow")
axs.plot(t/24,suma_2_mod, color="c")
axs.set(title='M2+S2+N2+K1+O1s',ylabel='Altura (m)',xlabel='días')
axs.legend(['M2+S2+N2','M2 + S2+N2+K1+O1'])
axs.grid(which='both',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,O1,color="r")
axs.plot(t/24,K1, color="c")
axs.set(title='O1 Y K1',ylabel='Altura (m)',xlabel='días')
axs.legend(['01','K1'])
axs.grid(which='both',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,O1,color="r")
axs.plot(t/24,suma_1, color="c")
axs.plot(t/24, K1, color="g")
axs.set(title='O1  y k1 y suma_1',ylabel='Altura (m)',xlabel='días')
axs.legend(['01','suma_1', "k1"])
axs.grid(which='both',ls=':')

# %% [markdown]
# PARTE 2

# %%
t=np.arange(0,24*365) # Eje temporal de un mes de datos horarios
S2=0.47*np.cos(np.deg2rad(30*t))
T2= 0.0587*np.cos(np.deg2rad(29.9589*t))
R2=0.0084*np.cos(np.deg2rad(30.0411*t + 180))

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot((t/24),S2,color="r")
axs.plot((t/24),T2, color="c")
axs.plot((t/24), R2, color="g")
axs.set(title='S2  y T2 y R2',ylabel='Altura (m)',xlabel='días')
axs.legend(['S2','T2', "R2"])
axs.grid(which='both',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot((t/24)[0:100],S2[0:100],color="r")
axs.plot((t/24)[0:100],T2[0:100], color="c")
axs.plot((t/24)[0:100], R2[0:100], color="g")
axs.set(title='S2  y T2 y R2',ylabel='Altura (m)',xlabel='días')
axs.legend(['S2','T2', "R2"])
axs.grid(which='both',ls=':')

# %%
Suma_4= S2 + T2 + R2
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot((t/24)[0:100],S2[0:100],color="m")
axs.plot((t/24)[0:100],Suma_4[0:100], color="coral")
axs.set(title='S2 +T2+R2',ylabel='Altura (m)',xlabel='días')
axs.legend(["S2",'S2 + T2 +R2'])
axs.grid(which='both',ls=':')

# %%
Suma_4= S2 + T2 + R2
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot((t/24),S2,color="m", alpha=0.5)
axs.plot((t/24),Suma_4, color="coral", alpha=0.5)
axs.set(title='S2 +T2+R2',ylabel='Altura (m)',xlabel='días')
axs.legend(["S2",'S2 + T2 +R2'])
axs.grid(which='both',ls=':')

# %%
M2=1*np.cos(np.deg2rad(28.9841*t))

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,S2,color="r")
axs.plot(t/24,Suma_4, color="coral", alpha=0.5)
axs.plot(t/24, M2, color="c", alpha= 0.5)
axs.set(title='S2 Y s2+tr+t2 y M2',ylabel='Altura (m)',xlabel='días')
axs.legend(['S2','Suma_4', "M2"])
axs.grid(which='both',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot((t/24)[100:200],S2[100:200],color="r")
axs.plot((t/24)[100:200],Suma_4[100:200], color="c")
axs.plot((t/24)[100:200], M2[100:200], color="coral", alpha= 0.5)
axs.set(title='S2 Y s2+tr+t2 y M2',ylabel='Altura (m)',xlabel='días')
axs.legend(['S2','Suma_4', "M2"])
axs.grid(which='both',ls=':')

# %%
Suma_5= S2 + T2 + R2 + M2
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot((t/24),Suma_4,color="m", alpha=0.5)
axs.plot((t/24),Suma_5, color="coral", alpha=0.5)
axs.set(title='S2 +T2+R2 + M2 ',ylabel='Altura (m)',xlabel='días')
axs.legend(["S2+ T2+R2 ",'S2 + T2 +R2 +M2'])
axs.grid(which='both',ls=':')
